# %%
from read_results_helpers import *
from clab_pypsa.run_pypsa import build_network, run_pypsa

# %%
# Set paths
input_file_name = "all_firm_case"
results_dir = "output_data/all_firm_case"
suffix = "all"

# Build network from file and run PyPSA for full network
network, case_dict, component_list = build_network(input_file_name+".xlsx")
run_pypsa(network, input_file_name+".xlsx", case_dict, component_list, outfile_suffix=suffix)

# Consecutively remove technology with largest total cost and rerun optimization
n_steps = 2

for step in range(n_steps):
    # Identify technology with largest total cost
    result_file_name = input_file_name.replace("case", suffix)
    # Load results
    component_results = read_component_results(results_dir, result_file_name+".pickle")
    # Calculate total costs
    costs = get_result(component_results, "cost")
    # Get technology with largest total cost
    max_key = max(costs, key=costs.get)
    
    # Remove technology with largest total cost from network
    for component_class in network.iterate_components():
        # Get method to get component carriers
        components = getattr(network, component_class[1])
        if hasattr(components, "carrier"):
            for carrier in components.carrier:
                if carrier == max_key:
                    # Get component name of component with this carrier
                    max_key_component_name = components[components.carrier == carrier].index[0]
                    print("Component name to be removed: {}".format(max_key_component_name))
                    # Remove component
                    network.remove(component_class[0], max_key_component_name)
    
    # Rerun optimization
    if suffix == "all":
        suffix = "no_"+max_key
    else:
        suffix += "_no_"+max_key
    run_pypsa(network, input_file_name+".xlsx", case_dict, component_list, outfile_suffix=suffix)
# Out:
# INFO:root:Using default value for Generator "solar" for capital_cost = 51369.65162195618
# INFO:root:Using default value for Generator "solar" for marginal_cost = 0.01
# INFO:root:Using default value for Generator "solar" for efficiency = 1.0
# INFO:root:Using default value for Generator "onwind" for capital_cost = 107318.83344708191
# INFO:root:Using default value for Generator "onwind" for marginal_cost = 1.5
# INFO:root:Using default value for Generator "onwind" for efficiency = 1.0
# INFO:root:Using default value for Generator "offwind" for capital_cost = 195863.98898328524
# INFO:root:Using default value for Generator "offwind" for marginal_cost = 0.02
# INFO:root:Using default value for Generator "offwind" for efficiency = 1.0
# INFO:root:Using default value for Generator "nuclear" for capital_cost = 706772.616768959
# INFO:root:Using default value for Generator "nuclear" for marginal_cost = 11.378787878787879
# INFO:root:Using default value for Generator "nuclear" for efficiency = 0.33
# INFO:root:Using default value for Generator "CCGT" for capital_cost = 104817.25515418572
# INFO:root:Using default value for Generator "CCGT" for marginal_cost = 40.29285714285714
# INFO:root:Using default value for Generator "CCGT" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % link" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % link" for efficiency2 = 0.2
# INFO:root:Using default value for Generator "biomass" for capital_cost = 278083.0653560446
# INFO:root:Using default value for Generator "biomass" for marginal_cost = 14.893617021276597
# INFO:root:Using default value for Generator "biomass" for efficiency = 0.47
# INFO:root:Using default value for Generator "geothermal" for capital_cost = 334482.19905928615
# INFO:root:Using default value for Generator "geothermal" for marginal_cost = 0.0
# INFO:root:Using default value for Generator "geothermal" for efficiency = 0.24
# INFO:root:Using default value for Generator "hydro" for capital_cost = 177345.2166194864
# INFO:root:Using default value for Generator "hydro" for marginal_cost = 0.0
# INFO:root:Using default value for Generator "hydro" for efficiency = 0.9
# INFO:root:Using default value for StorageUnit "battery storage" for capital_cost = 21899.158772435316
# INFO:root:Using default value for StorageUnit "battery storage" for marginal_cost = 0.0
# INFO:root:Using default value for Link "electrolysis" for capital_cost = 68776.83619343264
# INFO:root:Using default value for Link "electrolysis" for marginal_cost = 0.0
# INFO:root:Using default value for Link "electrolysis" for efficiency = 0.66
# INFO:root:Using default value for Store "hydrogen storage underground" for capital_cost = 210.24229380918007
# INFO:root:Using default value for Store "hydrogen storage underground" for marginal_cost = 0.0
# INFO:root:Using default value for Store "hydrogen storage underground" for efficiency = 1.0
# INFO:root:Using default value for Link "fuel cell" for capital_cost = 250090.75354557403
# INFO:root:Using default value for Link "fuel cell" for marginal_cost = 0.0
# INFO:root:Using default value for Link "fuel cell" for efficiency = 0.5
# INFO:root:Using default value for Generator "CCGT % wCCS" for capital_cost = 157225.8827312786
# INFO:root:Using default value for Generator "CCGT % wCCS" for marginal_cost = 60.4392857142857
# INFO:root:Using default value for Generator "CCGT % wCCS" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % wCCS link" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % wCCS link" for efficiency2 = 0.1
# INFO:root:Using default value for Link "direct air capture" for capital_cost = 1007250.4802027898
# INFO:root:Using default value for Link "direct air capture" for marginal_cost = 0.0
# INFO:root:Using default value for Link "direct air capture" for efficiency = 1.0
# INFO:root:Using default value for Link "direct air capture" for efficiency2 = -0.4
# INFO:root:Using default value for Store "CO2 storage tank" for capital_cost = 242.22527532177014
# INFO:root:Using default value for Store "CO2 storage tank" for marginal_cost = 0.0
# INFO:root:Using default value for Store "CO2 storage tank" for efficiency = 1.0
# INFO:root:Using default value for Generator "nuclear % heater" for capital_cost = 706772.616768959
# INFO:root:Using default value for Generator "nuclear % heater" for marginal_cost = 11.378787878787879
# INFO:root:Using default value for Generator "nuclear % heater" for efficiency = 0.33
# INFO:root:Using default value for Store "csp-tower TES" for capital_cost = 1758.282092150668
# INFO:root:Using default value for Store "csp-tower TES" for marginal_cost = 0.0
# INFO:root:Using default value for Store "csp-tower TES" for efficiency = 1.0
# INFO:root:Using default value for Link "nuclear % heat link" for efficiency = 0.33
# INFO:root:Using default value for Link "direct air capture % nuclear heat" for capital_cost = 1007250.4802027898
# INFO:root:Using default value for Link "direct air capture % nuclear heat" for marginal_cost = 0.0
# INFO:root:Using default value for Link "direct air capture % nuclear heat" for efficiency = 1.0
# INFO:root:Using default value for Link "direct air capture % nuclear heat" for efficiency2 = -0.4
# INFO:root:Using default value for Link "direct air capture % nuclear heat" for efficiency3 = -1.6
# INFO:root:Using default value for Generator "CCGT % heater" for capital_cost = 104817.25515418572
# INFO:root:Using default value for Generator "CCGT % heater" for marginal_cost = 40.29285714285714
# INFO:root:Using default value for Generator "CCGT % heater" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % heater link" for efficiency = 0.56
# INFO:root:Using default value for Link "CCGT % heater link" for efficiency2 = 0.2
# INFO:root:Using default value for Link "direct air capture % nat gas" for capital_cost = 1007250.4802027898
# INFO:root:Using default value for Link "direct air capture % nat gas" for marginal_cost = 0.0
# INFO:root:Using default value for Link "direct air capture % nat gas" for efficiency = 1.0
# INFO:root:Using default value for Link "direct air capture % nat gas" for efficiency2 = -0.4
# INFO:root:Using default value for Link "direct air capture % nat gas" for efficiency3 = -1.6
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 26/26 [00:02<00:00, 12.99it/s]
# Writing variables.: 100%|██████████| 12/12 [00:00<00:00, 37.43it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2024-01-05
# Read LP format model from file /private/var/folders/mb/bhrh7_m94j739pkhyn5p1l3w0000gn/T/linopy-problem-qnfgqexw.lp
# Reading time = 1.58 seconds
# obj: 694043 rows, 333858 columns, 1463350 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 694043 rows, 333858 columns and 1463350 nonzeros
# Model fingerprint: 0x85167d3a
# Coefficient statistics:
#   Matrix range     [1e-06, 4e+00]
#   Objective range  [3e-04, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 7e+05]
# Presolve removed 425478 rows and 117980 columns
# Presolve time: 0.91s
# Presolved: 268565 rows, 215878 columns, 867188 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.09s
#
# Barrier statistics:
#  Dense cols : 23
#  AA' NZ     : 9.236e+05
#  Factor NZ  : 3.541e+06 (roughly 230 MB of memory)
#  Factor Ops : 8.274e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.56539491e+13  0.00000000e+00  5.33e+07 0.00e+00  4.18e+10     2s
#    1   9.50420075e+13 -1.44935455e+13  1.65e+07 2.47e+03  1.97e+10     2s
#    2   1.02881828e+14 -9.39814650e+12  3.53e+06 7.34e+02  6.14e+09     2s
#    3   8.42680672e+13 -1.28370601e+12  4.20e+05 8.76e+01  8.81e+08     3s
#    4   3.73467647e+13 -2.70834196e+11  2.64e+04 1.34e+01  1.66e+08     4s
#    5   1.16463413e+13 -1.39952327e+11  2.99e+03 3.80e+00  4.17e+07     4s
#    6   4.24003341e+12 -9.85564067e+10  7.87e+02 1.18e+00  1.33e+07     4s
#    7   1.06487169e+12 -7.44842523e+10  1.60e+02 6.85e-01  4.00e+06     5s
#    8   7.31833211e+11 -8.37074716e+09  9.72e+01 3.48e-01  2.33e+06     5s
#    9   4.00429203e+11  5.62997430e+10  3.71e+01 1.28e-01  9.62e+05     5s
#   10   1.92713347e+11  8.76343194e+10  8.90e+00 1.83e-02  2.55e+05     6s
#   11   1.60846788e+11  9.16864995e+10  5.67e+00 1.12e-02  1.65e+05     6s
#   12   1.50905776e+11  9.35708476e+10  4.67e+00 8.79e-03  1.36e+05     6s
#   13   1.40855692e+11  9.64574149e+10  3.64e+00 5.72e-03  1.04e+05     7s
#   14   1.35175935e+11  9.76430878e+10  3.09e+00 4.72e-03  8.75e+04     7s
#   47   1.06016089e+11  1.06015995e+11  8.69e-05 4.52e-05  2.13e-01    17s
#   48   1.06016011e+11  1.06015996e+11  1.37e-05 4.31e-06  3.42e-02    17s
#   49   1.06015996e+11  1.06015996e+11  2.53e-07 4.94e-07  2.88e-04    17s
#   50   1.06015996e+11  1.06015996e+11  3.62e-08 1.87e-07  7.37e-08    18s
#   51   1.06015996e+11  1.06015996e+11  3.73e-09 1.01e-07  7.73e-14    18s
#
# Barrier solved model in 51 iterations and 17.95 seconds (6.64 work units)
# Optimal objective 1.06015996e+11
#
# Crossover log...
#
#   208487 DPushes remaining with DInf 0.0000000e+00                18s
#        0 DPushes remaining with DInf 0.0000000e+00                18s
#
#    17476 PPushes remaining with PInf 0.0000000e+00                18s
#        0 PPushes remaining with PInf 0.0000000e+00                19s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 8.6050298e-08     19s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    76771    1.0601600e+11   0.000000e+00   0.000000e+00     20s
#
# Solved in 76771 iterations and 19.53 seconds (11.08 work units)
# Optimal objective  1.060159957e+11
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 333858 primals, 694043 duals
# Objective: 1.06e+11
# Solver model: available
# Solver message: 2
#
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_all.xlsx
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_all.pickle
# Component name to be removed: hydro
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 26/26 [00:01<00:00, 14.03it/s]
# Writing variables.: 100%|██████████| 12/12 [00:00<00:00, 38.41it/s]
# Read LP format model from file /private/var/folders/mb/bhrh7_m94j739pkhyn5p1l3w0000gn/T/linopy-problem-nkkjkegf.lp
# Reading time = 1.52 seconds
# obj: 676472 rows, 325072 columns, 1428209 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 676472 rows, 325072 columns and 1428209 nonzeros
# Model fingerprint: 0x786ffeb8
# Coefficient statistics:
#   Matrix range     [1e-06, 4e+00]
#   Objective range  [3e-04, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 7e+05]
# Presolve removed 416692 rows and 117980 columns
# Presolve time: 0.85s
# Presolved: 259780 rows, 207092 columns, 840833 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.07s
#
# Barrier statistics:
#  Dense cols : 22
#  AA' NZ     : 9.061e+05
#  Factor NZ  : 3.495e+06 (roughly 200 MB of memory)
#  Factor Ops : 8.097e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.68979551e+13  0.00000000e+00  5.04e+07 0.00e+00  4.37e+10     2s
#    1   9.77949966e+13 -1.37510572e+13  1.49e+07 2.49e+03  2.04e+10     2s
#    2   1.04542250e+14 -8.61327879e+12  3.15e+06 7.22e+02  6.19e+09     2s
#    3   8.41004819e+13 -1.01503412e+12  2.86e+05 8.32e+01  8.61e+08     2s
#    4   3.53033328e+13 -1.89185481e+11  1.48e+04 1.15e+01  1.52e+08     3s
#    5   1.05158960e+13 -9.40603465e+10  1.75e+03 3.20e+00  3.75e+07     3s
#    6   2.70314126e+12 -6.01133075e+10  3.24e+02 9.05e-01  9.05e+06     3s
#    7   9.90193252e+11 -2.19883124e+10  9.34e+01 4.95e-01  3.42e+06     3s
#    8   6.76231888e+11  5.03371317e+10  5.59e+01 1.76e-01  1.80e+06     4s

#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 3.4141295e-09     14s
#
#
# Solved with barrier
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    90740    1.1505397e+11   0.000000e+00   0.000000e+00     14s
#
# Solved in 90740 iterations and 14.01 seconds (13.01 work units)
# Optimal objective  1.150539667e+11
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 325072 primals, 676472 duals
# Objective: 1.15e+11
# Solver model: available
# Solver message: 2
#
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_no_hydro.xlsx
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_no_hydro.pickle
# Component name to be removed: offwind
# INFO:linopy.model: Solve linear problem using Gurobi solver
# Writing constraints.: 100%|██████████| 25/25 [00:01<00:00, 13.59it/s]
# Writing variables.: 100%|██████████| 12/12 [00:00<00:00, 39.29it/s]
# Read LP format model from file /private/var/folders/mb/bhrh7_m94j739pkhyn5p1l3w0000gn/T/linopy-problem-3yr41vhx.lp
# Reading time = 1.46 seconds
# obj: 658901 rows, 316286 columns, 1393068 nonzeros
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[rosetta2])
#
# CPU model: Apple M1
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 658901 rows, 316286 columns and 1393068 nonzeros
# Model fingerprint: 0xaa8dbef3
# Coefficient statistics:
#   Matrix range     [1e-06, 4e+00]
#   Objective range  [3e-04, 1e+06]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [3e+05, 7e+05]
# Presolve removed 407906 rows and 117980 columns
# Presolve time: 0.81s
# Presolved: 250995 rows, 198306 columns, 814478 nonzeros
#
# Concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
#
# Ordering time: 0.06s
#
# Barrier statistics:
#  Dense cols : 21
#  AA' NZ     : 8.885e+05
#  Factor NZ  : 3.449e+06 (roughly 200 MB of memory)
#  Factor Ops : 7.923e+07 (less than 1 second per iteration)
#  Threads    : 6
#
#                   Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0   5.82306566e+13  0.00000000e+00  4.74e+07 0.00e+00  4.58e+10     2s
#    1   1.00150073e+14 -1.27967504e+13  1.39e+07 2.52e+03  2.12e+10     2s
#    2   1.06329963e+14 -7.77012500e+12  2.97e+06 7.10e+02  6.29e+09     2s
#    3   8.51900643e+13 -1.04305485e+12  2.92e+05 8.21e+01  8.85e+08     2s
#    4   3.49460254e+13 -1.89993996e+11  1.51e+04 1.14e+01  1.56e+08     2s
#    5   1.05549415e+13 -9.24517939e+10  2.01e+03 3.22e+00  3.94e+07     3s
#    6   2.59976329e+12 -5.18480811e+10  4.07e+02 8.69e-01  9.10e+06     3s
#    7   1.11056498e+12  1.43017500e+10  1.42e+02 4.10e-01  3.66e+06     3s
#    8   5.73606304e+11  8.21317602e+10  5.32e+01 1.70e-01  1.52e+06     3s
#    9   3.85124023e+11  1.05833455e+11  2.87e+01 5.03e-02  7.64e+05     4s
#   10   3.45455806e+11  1.21131642e+11  2.36e+01 2.63e-02  5.90e+05     4s
#   11   3.02228823e+11  1.27420776e+11  1.82e+01 2.14e-02  4.58e+05     4s
#   12   2.86636285e+11  1.36046770e+11  1.61e+01 1.66e-02  3.92e+05     4s
#   13   2.70772627e+11  1.42505794e+11  1.37e+01 1.37e-02  3.32e+05     5s
#   14   2.38640025e+11  1.57562205e+11  8.49e+00 7.70e-03  2.07e+05     5s
#   15   2.27463488e+11  1.61923099e+11  6.94e+00 5.57e-03  1.66e+05     5s
#   16   2.15883934e+11  1.65258602e+11  5.41e+00 3.53e-03  1.27e+05     5s
#   17   2.10205384e+11  1.67298795e+11  4.66e+00 2.33e-03  1.08e+05     6s
#   18   2.00936576e+11  1.68577632e+11  3.47e+00 1.76e-03  8.09e+04     6s
#   19   1.98932399e+11  1.70334780e+11  3.20e+00 1.04e-03  7.13e+04     6s
#   20   1.93765995e+11  1.70748650e+11  2.51e+00 8.66e-04  5.73e+04     6s
#   21   1.91617697e+11  1.71190637e+11  2.22e+00 6.88e-04  5.08e+04     7s
#   22   1.87767835e+11  1.72049798e+11  1.72e+00 2.55e-04  3.90e+04     7s
#   23   1.87392088e+11  1.72424680e+11  1.67e+00 1.46e-04  3.71e+04     7s
#   24   1.82280868e+11  1.73323675e+11  9.19e-01 2.19e-05  2.22e+04     8s
#   25   1.81195433e+11  1.74106274e+11  7.74e-01 5.79e-06  1.76e+04     8s
#   26   1.78776271e+11  1.74578527e+11  4.62e-01 8.38e-09  1.04e+04     8s
#   27   1.78021404e+11  1.74796394e+11  3.61e-01 9.19e-08  7.97e+03     8s
#   28   1.76734957e+11  1.74987655e+11  1.91e-01 2.53e-09  4.32e+03     9s
#   29   1.75634922e+11  1.75028919e+11  6.18e-02 3.03e-09  1.50e+03     9s
#   30   1.75330687e+11  1.75059768e+11  2.65e-02 3.26e-09  6.69e+02     9s
#   31   1.75175068e+11  1.75073890e+11  9.22e-03 2.44e-09  2.50e+02     9s
#   32   1.75085698e+11  1.75080734e+11  2.64e-04 2.37e-07  1.23e+01    10s
#   33   1.75082655e+11  1.75082088e+11  4.54e-05 3.40e-07  1.41e+00    10s
#   34   1.75082623e+11  1.75082556e+11  7.95e-06 2.69e-07  1.67e-01    10s
#   35   1.75082611e+11  1.75082611e+11  3.47e-08 4.19e-09  9.75e-04    10s
#   36   1.75082611e+11  1.75082611e+11  3.73e-09 5.45e-08  1.06e-07    11s
#   37   1.75082611e+11  1.75082611e+11  3.73e-09 5.87e-08  6.25e-13    11s
#
# Barrier solved model in 37 iterations and 10.82 seconds (4.99 work units)
# Optimal objective 1.75082611e+11
#
# Crossover log...
#
#   186261 DPushes remaining with DInf 0.0000000e+00                11s
#        0 DPushes remaining with DInf 0.0000000e+00                12s
#
#    15578 PPushes remaining with PInf 0.0000000e+00                12s
#        0 PPushes remaining with PInf 0.0000000e+00                13s
#
#   Push phase complete: Pinf 0.0000000e+00, Dinf 1.0185515e+04     13s
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    89854    1.7508261e+11   0.000000e+00   1.018551e+04     13s
#
# Solved with barrier
#    89966    1.7508261e+11   0.000000e+00   0.000000e+00     13s
#
# Solved in 89966 iterations and 13.37 seconds (12.98 work units)
# Optimal objective  1.750826110e+11
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 316286 primals, 658901 duals
# Objective: 1.75e+11
# Solver model: available
# Solver message: 2
#
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_no_offwind.xlsx
# INFO:root:Results written to file: output_data/all_firm_case/all_firm_no_offwind.pickle
